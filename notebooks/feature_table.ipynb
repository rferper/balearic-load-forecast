# %%
from pathlib import Path
from balearic_load_forecast.io.datasets import load_demand
from balearic_load_forecast.domain.features import make_training_table

s = load_demand(Path("../data/balearic_demand_raw.csv"))
table = make_training_table(s)
table.head()
# Out:
#                            hour  dayofweek  is_weekend  month  dayofyear  \
# datetime
# 2011-01-14 23:00:00+00:00     0          5           1      1         15
# 2011-01-15 00:00:00+00:00     1          5           1      1         15
# 2011-01-15 01:00:00+00:00     2          5           1      1         15
# 2011-01-15 02:00:00+00:00     3          5           1      1         15
# 2011-01-15 03:00:00+00:00     4          5           1      1         15
#
#                            is_holiday  lag_48h  lag_168h  lag_336h  \
# datetime
# 2011-01-14 23:00:00+00:00           0  805.731   861.834   905.611
# 2011-01-15 00:00:00+00:00           0  726.995   777.804   855.654
# 2011-01-15 01:00:00+00:00           0  689.311   722.977   794.808
# 2011-01-15 02:00:00+00:00           0  675.298   698.482   748.105
# 2011-01-15 03:00:00+00:00           0  675.651   691.193   720.198
#
#                            roll_7d_mean  roll_7d_max   target
# datetime
# ...
